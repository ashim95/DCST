# %%
from examples import syllable_encoding
from indic_transliteration import sanscript
from indic_transliteration.sanscript import SchemeMap, SCHEMES, transliterate

# %%
text = transliterate('anujaH', sanscript.SLP1, sanscript.DEVANAGARI)
# text = "अ॒ग्निमी॑ळे"
''.join(syllable_encoding.syllabify(text)[-2:])
# Out:
# 'नुजः'

# %%
stats = syllable_encoding.getSyllableStats(text)
for k, v in stats.items():
    print (k)
    for x, y in v.items():
        print ("\t", x, ":", y)
    print ("total", k, "=", sum(v.values()))
    print ("unique", k, "=", len(v), end='\n\n')
# Out:
# words
# 	 अ॒ग्निमी॑ळे : 1
# total words = 1
# unique words = 1
#
# syllables
# 	 अ॒ : 1
# 	 ग्नि : 1
# 	 मी॑ : 1
# 	 ळे : 1
# total syllables = 4
# unique syllables = 4

# %%
mydict = dict()
mydict['True'] = 1
print()
# Out:
# True

# %%
files = os.listdir('./data/Rules/')
for file in files:
    
    break
data
# Out:
#      0   1  2   3   4  5                      6      7                     8
# 0    0  11  1   9  13  1  #karwqsamAnAXikaraNam  25.1a  karwqsamanaxikaranam
# 1    1  11  1   7  13  1                 #karwA    1.2                 karwa
# 2    2  10  1   9  13  1  #karwqsamAnAXikaraNam  25.1a  karwqsamanaxikaranam
# 3    3  10  1   7  13  1                 #karwA    1.2                 karwa
# 4    4   9  2  34  11  1                 #hewuH   24.1                 hewuh
# 5    5   9  2  35  11  1        #RaRTIsambanXaH   20.6        rartisambanxah
# 6    6   9  2  35  10  1        #RaRTIsambanXaH   20.6        rartisambanxah
# 7    7   8  1  25  13  1            #aXikaraNam   3.23            axikaranam
# 8    8   7  1  34  11  1                 #hewuH   24.1                 hewuh
# 9    9   7  1  35  11  1        #RaRTIsambanXaH   20.6        rartisambanxah
# 10  10   7  1  35  10  1        #RaRTIsambanXaH   20.6        rartisambanxah
# ...

# %%
import ast
import os
import pandas as pd
file = 'Gold_1132'
data = pd.read_csv('./data/Rules/rule_'+file,header=None,sep=',')
data
# temp = dict()
# if "Gold" in file:
#     temp.update({-1:{'Gold'}})
# else:
#     temp.update({-1:{'Eval'}})
# for i in range(len(data)):
#     temp.update({i: {data.iloc[i,1],data.iloc[i,4],data.iloc[i,-1]}})
# res = ast.literal_eval(str(temp))
# Out:
#      0   1  2     3   4  5                   6      7                 8
# 0    0  11  7    35  13  3     #RaRTIsambanXaH   20.6    rartisambanxah
# 1    2  11  6    41  14  1         #prayojanam   3.10  upapaxasambanxah
# 2    3  11  1     7  14  1              #karwA    1.2             karwa
# 3    4   9  1  4100  14  1  #xeSAXikaraNam_upa   18.4        axikaranam
# 4    5   9  1  4100   5  2  #xeSAXikaraNam_upa   18.4        axikaranam
# 5    8   8  1  4100  14  1  #xeSAXikaraNam_upa   18.1        axikaranam
# 6    9   7  1    44  14  1            #anuyogI  37.3a  upapaxasambanxah
# 7   10   6  1    28   5  2          #sambanXaH   27.1         sambanxah
# 8   12   6  1    44  14  1            #anuyogI   41.4  upapaxasambanxah
# 9   13   5  2     3   7  1          #prawiyogI  37.3a         prawiyogi
# 10  14   5  2     3   6  1          #prawiyogI   41.3         prawiyogi
# 11  17   3  2    47  14  1          #samboXyaH   3.24         samboxyah
# ...

# %%
file
# Out:
# 'Gold_1132'

# %%
data = pd.read_csv('./data/sanskrit_treebank/train/'+file,header=None,sep=',')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-3d313ba93218> in <module>
# ----> 1 data = pd.read_csv('./data/sanskrit_treebank/train/'+file,header=None,sep=',')
#       2 data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
import torch
x = torch.rand(2, 2)
y = torch.rand(3,2,4)
x
# Out:
# tensor([[0.8195, 0.6815],
#         [0.6887, 0.4983]])

# %%
y[1,1,1:]
# Out:
# tensor([0.1727, 0.1259, 0.9072])

# %%
x.unsqueeze(0)+y
# Out:
# tensor([[[1.0201, 0.9442],
#          [1.4542, 1.1683]],
#
#         [[1.3819, 1.1861],
#          [0.9173, 1.6272]],
#
#         [[1.3302, 0.7482],
#          [0.9709, 1.0617]]])

# %%
def test(flag= True):
    if flag == False:
        print('yes')
    else:
        print('no')
      
test(flag=False)
# Out:
# yes
